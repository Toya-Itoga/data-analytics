# %% [markdown]
# ### 目的
# ピタゴラス勝率と重回帰分析を用いた勝率の推定および比較

# %% [markdown]
# ### 分析

# %% [markdown]
# #### ライブラリ・データ読み込み

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression as LR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE

# %%
df = pd.read_csv('パスを指定')
df.head(10)
# Out:
#    teamIDfg  Season Team  Age     G    AB    PA     H   1B   2B  ...  xwOBA  \
# 0        21    2019  HOU   28  2309  5613  6394  1538  899  323  ...    NaN
# 1         8    2019  MIN   27  2320  5732  6392  1547  899  318  ...    NaN
# 2         9    2019  NYY   28  2312  5583  6245  1493  880  290  ...    NaN
# 3        22    2019  LAD   28  2413  5493  6281  1414  813  302  ...    NaN
# 4         3    2019  BOS   29  2455  5770  6475  1554  937  345  ...    NaN
# 5        24    2019  WSN   29  2327  5512  6267  1460  904  298  ...    NaN
# 6        16    2019  ATL   28  2411  5560  6302  1432  877  277  ...    NaN
# 7        17    2019  CHC   29  2429  5461  6195  1378  826  270  ...    NaN
# 8        19    2019  COL   28  2452  5660  6288  1502  914  323  ...    NaN
# 9        10    2019  OAK   29  2363  5561  6269  1384  812  292  ...    NaN
#
#    L-WAR  Games  R_per_game  HR_per_game                    Tm    W   L  \
# 0   42.1    162    5.679012     1.777778        Houston Astros  107  55
# 1   31.8    162    5.796296     1.895062       Minnesota Twins  101  61
# 2   30.6    162    5.820988     1.888889      New York Yankees  103  59
# 3   34.4    162    5.469136     1.722222   Los Angeles Dodgers  106  56
# 4   27.9    162    5.561728     1.512346        Boston Red Sox   84  78
# 5   28.2    162    5.388889     1.425926  Washington Nationals   93  69
# 6   27.4    162    5.277778     1.537037        Atlanta Braves   97  65
# 7   25.5    162    5.024691     1.580247          Chicago Cubs   84  78
# 8   11.7    162    5.154321     1.382716      Colorado Rockies   71  91
# 9   26.2    162    5.216049     1.586420     Oakland Athletics   97  65
#
#     W-L%   RA
# 0  0.660  640
# 1  0.623  754
# 2  0.636  739
# 3  0.654  613
# 4  0.519  828
# 5  0.574  724
# 6  0.599  743
# 7  0.519  717
# 8  0.438  958
# 9  0.599  680
#
# [10 rows x 327 columns]

# %%
df.shape
df = df.dropna()
df.shape
# Out:
# (0, 327)

# %% [markdown]
# #### ピタゴラス勝率

# %%
Pythagoreas_win_rate = (df['R'] ** 2) / (df['R'] ** 2 + df['RA'] ** 2)
Pythagoreas_win_rate.head()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# #### 重回帰分析

# %%
X = df[['R', 'RA']]
y = df['W-L%']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(f'X_train: {X_train.shape}')
print(f'X_test: {X_test.shape}')
print(f'y_train: {y_train.shape}')
print(f'y_test: {y_test.shape}')

model = LR()
model.fit(X_train, y_train)

y_pred_test = model.predict(X_test)
# Out:
# X_train: (105, 2)
# X_test: (45, 2)
# y_train: (105,)
# y_test: (45,)

# %% [markdown]
# #### 定量評価

# %%
mse_Pythagoreas_win_rate = MSE(df['W-L%'], Pythagoreas_win_rate)
rmse_Pythagoreas_win_rate = np.sqrt(mse_Pythagoreas_win_rate)

mse_linear = MSE(y_test, y_pred_test)
rmse_linear = np.sqrt(mse_linear)

print(f"ピタゴラス勝率RMSE: {rmse_Pythagoreas_win_rate}")
print(f"重回帰分析RMSE: {rmse_linear}")
# Out:
# ピタゴラス勝率RMSE: 0.028485711473543746
# 重回帰分析RMSE: 0.04092355887653523

# %% [markdown]
# ### 結論
# ピタゴラス勝率と重回帰分析、両者のRMSEを比較するとピタゴラス勝率の方が値が小さいため正確であると言える
